# %% [markdown]
# Lab based on: https://datahack.analyticsvidhya.com/contest/practice-problem-loan-prediction-iii/#About

# %% [markdown]
# # Step 1 : Reading and understanding Train and Test Data set¶

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\samhe\anaconda3\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\samhe\anaconda3\lib\site-packages (from seaborn) (1.24.3)
# Requirement already satisfied: pandas>=0.25 in c:\users\samhe\anaconda3\lib\site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\samhe\anaconda3\lib\site-packages (from seaborn) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\samhe\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\samhe\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\samhe\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\samhe\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\samhe\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\samhe\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\samhe\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\samhe\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\samhe\anaconda3\lib\site-packages (from pandas>=0.25->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\samhe\anaconda3\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\samhe\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)

# %%
#Loading Packages
import pandas as pd 
import numpy as np                     # For mathematical calculations 
import seaborn as sns                  # For data visualization 
import matplotlib.pyplot as plt        # For plotting graphs 
# %matplotlib inline 
import warnings                        # To ignore any warnings warnings.filterwarnings("ignore")

train_original = pd.read_csv("input/train_ctrUa4K.csv")
train = train_original
train.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
#Reading the name of columns in data set 
train.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
test = pd.read_csv("input/test_lAUu6dG.csv")
test.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# 3             NaN         Urban
# 4             1.0         Urban

# %%
#Reading the name of columns in data set 
test.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')

# %% [markdown]
# # What are the data types present in the data?

# %% [markdown]
# R: Los tipos de datos presentes en la base de datos desde Loan_ID hasta Self_Employed son de tipo object que en este caso representan una String, AplicantIncome y CoapplicantIncome son Integer, desde LoanAmount hasta Credit_History son Float y por último Property_Area es de tipo object (String).

# %%
train.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
train = train.drop(columns=['Loan_ID'])

# %% [markdown]
# # Count, and treat missing values

# %%
missing_values = train.isna().sum()
missing_values
# Out:
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
gender_mode = train['Gender'].mode()[0]
married_mode = train['Married'].mode()[0]
self_employed_mode = train['Self_Employed'].mode()[0]
dependents_mode = train['Dependents'].mode()[0]
credit_history_mode = train['Credit_History'].mode()[0]

# %%
train['Gender'] = train['Gender'].fillna(gender_mode)
train['Married'] = train['Married'].fillna(married_mode)
train['Self_Employed'] = train['Self_Employed'].fillna(self_employed_mode)
train['Dependents'] = train['Dependents'].fillna(dependents_mode)
train['Credit_History'] = train['Credit_History'].fillna(credit_history_mode)

# %%
loan_amount_mean = train['LoanAmount'].mean()
loan_amount_term_mean = train['Loan_Amount_Term'].mean()

# %%
train['LoanAmount'] = train['LoanAmount'].fillna(loan_amount_mean)
train['Loan_Amount_Term'] = train['Loan_Amount_Term'].fillna(loan_amount_term_mean)

# %%
missing_values = train.isna().sum()
missing_values
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %% [markdown]
# # Format Correction

# %%
train = train.convert_dtypes()

# %%
train['Dependents'] = train['Dependents'].replace('3+', '3')

train['Dependents'] = train['Dependents'].astype('Int64')
train['Loan_Amount_Term'] = train['Loan_Amount_Term'].astype('Int64')
train['CoapplicantIncome'] = train['CoapplicantIncome'].astype('Int64')
train['LoanAmount'] = train['LoanAmount'].astype('Int64')
train['Credit_History']= train['Credit_History'].astype('string[python]')

# %%
train.dtypes
# Out:
# Gender               string[python]
# Married              string[python]
# Dependents                    Int64
# Education            string[python]
# Self_Employed        string[python]
# ApplicantIncome               Int64
# CoapplicantIncome             Int64
# LoanAmount                    Int64
# Loan_Amount_Term              Int64
# Credit_History       string[python]
# Property_Area        string[python]
# Loan_Status          string[python]
# dtype: object

# %% [markdown]
# # Univariate Analysis
# It is the simplest form of analyzing data where we examine each variable individually. For categorical features we can use frequency table or bar plots which will calculate the number of each category in a particular variable. For numerical features, probability density plots can be used to look at the distribution of the variable
#
# ## visualize features of the data set by graph and get the analysis
#
# ## Study categorical features such as Gender, Married, Self_Employed and Credit_History
#
# ## visualize the numerical variables: distribution of Applicant income first.

# %% [markdown]
# # Gender

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Gender', data=train)
plt.title('Count of Applicants by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.grid(axis='y')
plt.show()

# %%
gender_frequency = train['Gender'].value_counts()
gender_frequency
# Out:
# Gender
# Male      502
# Female    112
# Name: count, dtype: Int64

# %% [markdown]
# # Married

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Married', data=train)
plt.title('Count of Married Applicants')
plt.xlabel('Married')
plt.ylabel('Count')
plt.grid(axis='y')
plt.show()

# %%
married_frequency = train['Married'].value_counts()
married_frequency
# Out:
# Married
# Yes    401
# No     213
# Name: count, dtype: Int64

# %% [markdown]
# # Self Employed

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Self_Employed', data=train)
plt.title('Count of Self Employed Applicants')
plt.xlabel('Self Employed')
plt.ylabel('Count')
plt.grid(axis='y')
plt.show()

# %%
self_employed_frequency = train['Self_Employed'].value_counts()
self_employed_frequency
# Out:
# Self_Employed
# No     532
# Yes     82
# Name: count, dtype: Int64

# %% [markdown]
# # Credit History

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Credit_History', data=train)
plt.title('Count of Applicants by Credit History')
plt.xlabel('Credit History')
plt.ylabel('Count')
plt.grid(axis='y')
plt.show()

# %%
credit_history_frequency = train['Credit_History'].value_counts()
credit_history_frequency
# Out:
# Credit_History
# 1    525
# 0     89
# Name: count, dtype: Int64

# %% [markdown]
# # Applicant Income

# %%
plt.figure(figsize=(10, 6))
sns.distplot(train['ApplicantIncome'], bins=30, color='blue', kde=True)
plt.title('Distribution of Applicant Income')
plt.xlabel('Income')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\samhe\AppData\Local\Temp\ipykernel_14728\2112431605.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train['ApplicantIncome'], bins=30, color='blue', kde=True)

# %%
applicant_income_stats = train['ApplicantIncome'].describe()

skewness = train['ApplicantIncome'].skew()
kurtosis = train['ApplicantIncome'].kurt()

(applicant_income_stats, skewness, kurtosis)
# Out:
# (count          614.0
#  mean     5403.459283
#  std      6109.041673
#  min            150.0
#  25%           2877.5
#  50%           3812.5
#  75%           5795.0
#  max          81000.0
#  Name: ApplicantIncome, dtype: Float64,
#  6.539513113994625,
#  60.54067593369113)

# %% [markdown]
# # Bivariate Analysis
# Analyse the independent variable with respect to target variable.
#
# ## Use bar plots to vizualice Gender vs Loan_Status, Education vs Loan_Status, Property_Area vs Loan_Status
#
# ## identify the most correlated variables to Loan_Status

# %% [markdown]
# # Gender vs Loan Status

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Gender', hue='Loan_Status', data=train)
plt.title('Loan Status by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.grid(axis='y')
plt.show()

# %%
gender_loan_status = train.groupby('Gender')['Loan_Status'].value_counts(normalize=True).unstack() * 100
gender_loan_status
# Out:
# Loan_Status          N          Y
# Gender
# Female       33.035714  66.964286
# Male         30.876494  69.123506

# %% [markdown]
# # Education vs Loan Status

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Education', hue='Loan_Status', data=train)
plt.title('Loan Status by Education')
plt.xlabel('Education')
plt.ylabel('Count')
plt.grid(axis='y')
plt.show()

# %%
education_loan_status = train.groupby('Education')['Loan_Status'].value_counts(normalize=True).unstack() * 100
education_loan_status
# Out:
# Loan_Status           N          Y
# Education
# Graduate      29.166667  70.833333
# Not Graduate  38.805970  61.194030

# %% [markdown]
# # Property Area vs Loan Status

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Property_Area', hue='Loan_Status', data=train)
plt.title('Loan Status by Property Area')
plt.xlabel('Property Area')
plt.ylabel('Count')
plt.grid(axis='y')
plt.show()

# %%
property_area_loan_status = train.groupby('Property_Area')['Loan_Status'].value_counts(normalize=True).unstack() * 100
property_area_loan_status
# Out:
# Loan_Status            N          Y
# Property_Area
# Rural          38.547486  61.452514
# Semiurban      23.175966  76.824034
# Urban          34.158416  65.841584

# %% [markdown]
# # Indicator Variables

# %%
train['Loan_Status'] = train['Loan_Status'].map({'Y': True, 'N': False})

# %%
dummy_variable = pd.get_dummies(train['Gender'])
dummy_variable.head()
# Out:
#    Female  Male
# 0   False    True
# 1   False    True
# 2   False    True
# 3   False    True
# 4   False    True

# %%
train = train.join(dummy_variable)
train = train.drop(columns=['Gender'])

# %%
train['Married'] = train['Married'].map({'Yes': True, 'No': False})

# %%
dummy_variable_1 = pd.get_dummies(train['Education'])
dummy_variable_1.head()
# Out:
#    Graduate      Not Graduate
# 0          True         False
# 1          True         False
# 2          True         False
# 3         False          True
# 4          True         False

# %%
train = train.join(dummy_variable_1)
train = train.drop(columns=['Education'])

# %%
train['Self_Employed'] = train['Self_Employed'].map({'Yes': True, 'No': False})

# %%
dummy_variable_2 = pd.get_dummies(train['Property_Area'])
dummy_variable_2.head()
# Out:
#    Rural      Semiurban  Urban
# 0      False      False       True
# 1       True      False      False
# 2      False      False       True
# 3      False      False       True
# 4      False      False       True

# %%
train = train.join(dummy_variable_2)
train = train.drop(columns=['Property_Area'])

# %%
train['Credit_History'] = train['Credit_History'].map({'1': True, '0': False})

# %%
train.head()
# Out:
#    Married  Dependents  Self_Employed  ApplicantIncome  CoapplicantIncome  \
# 0    False           0          False             5849                  0
# 1     True           1          False             4583               1508
# 2     True           0           True             3000                  0
# 3     True           0          False             2583               2358
# 4    False           0          False             6000                  0
#
#    LoanAmount  Loan_Amount_Term  Credit_History  Loan_Status  Female  Male  \
# 0         146               360            True         True   False  True
# 1         128               360            True        False   False  True
# 2          66               360            True         True   False  True
# 3         120               360            True         True   False  True
# 4         141               360            True         True   False  True
#
#    Graduate  Not Graduate  Rural  Semiurban  Urban
# 0      True         False  False      False   True
# 1      True         False   True      False  False
# 2      True         False  False      False   True
# 3     False          True  False      False   True
# 4      True         False  False      False   True

# %% [markdown]
# # Correlation Matrix

# %%
correlation_matrix = train.corr(numeric_only=True)

plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation Matrix of Variables')
plt.show()

# %%
loan_status_correlation = correlation_matrix['Loan_Status'].drop('Loan_Status')

loan_status_correlation_sorted = loan_status_correlation.sort_values(ascending=False)

plt.figure(figsize=(10, 8))
sns.barplot(x=loan_status_correlation_sorted.values, y=loan_status_correlation_sorted.index, palette='viridis')
plt.title('Correlación de Variables con el Loan Status')
plt.xlabel('Coeficiente de Correlación')
plt.ylabel('Variables')

plt.show()

# %%
loan_status_correlation_sorted
# Out:
# Credit_History       0.540556
# Semiurban            0.136540
# Married              0.091478
# Graduate             0.085884
# Male                 0.017987
# Dependents           0.010118
# Self_Employed       -0.003700
# ApplicantIncome     -0.004710
# Female              -0.017987
# Loan_Amount_Term    -0.020974
# LoanAmount          -0.036345
# Urban               -0.043621
# CoapplicantIncome   -0.059188
# Not Graduate        -0.085884
# Rural               -0.100694
# Name: Loan_Status, dtype: float64

# %% [markdown]
# La variable más correlacionada con Loan_Status es Credit_History

# %% [markdown]
# # Treat Outliers

# %%
column_types = train.dtypes
columns = column_types[(column_types != 'string[python]')].index.tolist()

plt.figure(figsize=(10, 6))
train[columns].boxplot()

plt.title('Diagrama de Cajas')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Applicant Income Outliers

# %%
atr = 'ApplicantIncome'
ax = sns.boxplot(x=train[atr])

arr1 = train[atr].values
q1 = np.quantile(arr1, 0.25)
q3 = np.quantile(arr1, 0.75)
med = np.median(arr1)
iqr = q3-q1
upper_bound = q3+(1.5*iqr)
lower_bound = q1-(1.5*iqr)

applicant_outliers = arr1[(arr1 <= lower_bound) | (arr1 >= upper_bound)]
print('The following are the outliers in {} : {}'.format(atr,applicant_outliers))
print('Total number of outliers: ',applicant_outliers.size)
print('Percentage of outliers: ',applicant_outliers.size*100/train['ApplicantIncome'].count())
# Out:
# The following are the outliers in ApplicantIncome : <IntegerArray>
# [12841, 12500, 11500, 10750, 13650, 11417, 14583, 10408, 23803, 10513, 20166,
#  14999, 11757, 14866, 39999, 51763, 33846, 39147, 12000, 11000, 16250, 14683,
#  11146, 14583, 20667, 20233, 15000, 63337, 19730, 15759, 81000, 14880, 12876,
#  10416, 37719, 16692, 16525, 16667, 10833, 18333, 17263, 20833, 13262, 17500,
#  11250, 18165, 19484, 16666, 16120, 12000]
# Length: 50, dtype: Int64
# Total number of outliers:  50
# Percentage of outliers:  8.143322475570033

# %% [markdown]
# # Coapplicant Income Outliers

# %%
atr = 'CoapplicantIncome'
ax = sns.boxplot(x=train[atr])

arr1 = train[atr].values
q1 = np.quantile(arr1, 0.25)
q3 = np.quantile(arr1, 0.75)
med = np.median(arr1)
iqr = q3-q1
upper_bound = q3+(1.5*iqr)
lower_bound = q1-(1.5*iqr)

coapplicant_outliers = arr1[(arr1 <= lower_bound) | (arr1 >= upper_bound)]
print('The following are the outliers in {} : {}'.format(atr,coapplicant_outliers))
print('Total number of outliers: ',coapplicant_outliers.size)
print('Percentage of outliers: ',coapplicant_outliers.size*100/train['CoapplicantIncome'].count())
# Out:
# The following are the outliers in CoapplicantIncome : <IntegerArray>
# [10968,  8106,  7210,  8980,  7750, 11300,  7250,  7101,  6250,  7873, 20000,
#  20000,  8333,  6667,  6666,  7166, 33837, 41667]
# Length: 18, dtype: Int64
# Total number of outliers:  18
# Percentage of outliers:  2.9315960912052117

# %% [markdown]
# # Deleting Outliers

# %%
train = train.loc[~train['ApplicantIncome'].isin(applicant_outliers)]
train = train.loc[~train['CoapplicantIncome'].isin(coapplicant_outliers)]

train = train.reset_index(drop=True)

# %%
plt.figure(figsize=(10, 6))
train[['ApplicantIncome','CoapplicantIncome']].boxplot()

plt.title('Diagrama de Cajas sin outliers')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Model Building
#
# ## Using the train dataset you should be able to select the best model.
# ## Use feature selection
# ## Cross validation
# ## Try different models such as:
#
# 1) Decision Tree Classifier
# 2) Random Forest Classifier
# 3) K-Nearest-Neighbors
# 4) Support Vector Classifier
# 5) XGBoost

# %% [markdown]
# The test dataset doesn't have target. You are provided with a sample submition file. It is necesary to generate such a file with the two best models you have and attach it to your report.
